# %% [markdown]
# # PPP for Japan

# %%
import pandas as pd
ppp = pd.read_csv('ppp.csv')

# %%
jp_df = ppp[ppp['LOCATION']=='JPN']
jp_ppp = list(jp_df['Value'])
jp_ppp
year = list(jp_df['TIME'])
year
# Out:
# [2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017,
#  2018,
#  2019,
#  2020,
#  2021,
#  2022]

# %% [markdown]
# # PPP for USA

# %%
us_df = ppp[ppp['LOCATION']=='USA'] 
us_df
# Out:
#     LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value  Flag Codes
# 667      USA       PPP     TOT  NATUSD         A  2000    1.0         NaN
# 668      USA       PPP     TOT  NATUSD         A  2001    1.0         NaN
# 669      USA       PPP     TOT  NATUSD         A  2002    1.0         NaN
# 670      USA       PPP     TOT  NATUSD         A  2003    1.0         NaN
# 671      USA       PPP     TOT  NATUSD         A  2004    1.0         NaN
# 672      USA       PPP     TOT  NATUSD         A  2005    1.0         NaN
# 673      USA       PPP     TOT  NATUSD         A  2006    1.0         NaN
# 674      USA       PPP     TOT  NATUSD         A  2007    1.0         NaN
# 675      USA       PPP     TOT  NATUSD         A  2008    1.0         NaN
# 676      USA       PPP     TOT  NATUSD         A  2009    1.0         NaN
# 677      USA       PPP     TOT  NATUSD         A  2010    1.0         NaN
# 678      USA       PPP     TOT  NATUSD         A  2011    1.0         NaN
# 679      USA       PPP     TOT  NATUSD         A  2012    1.0         NaN
# 680      USA       PPP     TOT  NATUSD         A  2013    1.0         NaN
# 681      USA       PPP     TOT  NATUSD         A  2014    1.0         NaN
# 682      USA       PPP     TOT  NATUSD         A  2015    1.0         NaN
# 683      USA       PPP     TOT  NATUSD         A  2016    1.0         NaN
# 684      USA       PPP     TOT  NATUSD         A  2017    1.0         NaN
# 685      USA       PPP     TOT  NATUSD         A  2018    1.0         NaN
# 686      USA       PPP     TOT  NATUSD         A  2019    1.0         NaN
# 687      USA       PPP     TOT  NATUSD         A  2020    1.0         NaN
# 688      USA       PPP     TOT  NATUSD         A  2021    1.0         NaN
# 689      USA       PPP     TOT  NATUSD         A  2022    1.0         NaN

# %%
#since all us value is equal to 1 we only need to compare yen

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(year,jp_ppp)
plt.xlabel("Year")
plt.ylabel("PPP value")
plt.title("Japanese yen ppp value")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
