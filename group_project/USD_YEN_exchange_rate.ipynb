# %%
import pandas as pd
import seaborn as sns

# %%
exchange = pd.read_csv("USD_YEN_exchange.csv")

# %%
sns.lineplot(x = "Date", y = "Value", data= exchange)
plt.ylabel("1 USD to YEN")
plt.xlabel("Date(1971/1/4-2023/4/25)")
plt.show()

# %%
exchange['Value']
# Out:
#              Date     Value
# 0      1971-01-04  357.7300
# 1      1971-01-05  357.8100
# 2      1971-01-06  357.8600
# 3      1971-01-07  357.8700
# 4      1971-01-08  357.8200
# ...           ...       ...
# 13474  2023-04-20  134.1740
# 13475  2023-04-21  134.1650
# 13476  2023-04-22  134.1650
# 13477  2023-04-24  134.1065
# 13478  2023-04-25  133.8560
#
# [13479 rows x 2 columns]
